# %% [markdown]
# # Load Dataset

# %%
import pandas as pd

data = pd.read_csv("athletes.csv")
display(data)
# Out:
#         athlete_id             name               region  \
# 0           2554.0        Pj Ablang           South West
# 1           3517.0    Derek Abdella                  NaN
# 2           4691.0              NaN                  NaN
# 3           5164.0      Abo Brandon  Southern California
# 4           5286.0      Bryce Abbey                  NaN
# ...            ...              ...                  ...
# 423001    574489.0       Odo Renata        Latin America
# 423002    585696.0    Lozzie Trevor            Australia
# 423003    608828.0    Marisol Smith           North West
# 423004    628881.0  Pedrini Morgane               Europe
# 423005    631847.0       Eden Kenny  Northern California
#
#                            team              affiliate  gender   age  height  \
# 0                   Double Edge   Double Edge CrossFit    Male  24.0    70.0
# 1                           NaN                    NaN    Male  42.0    70.0
# 2                           NaN                    NaN     NaN   NaN     NaN
# 3                  LAX CrossFit           LAX CrossFit    Male  40.0    67.0
# 4                           NaN                    NaN    Male  32.0    65.0
# ...                         ...                    ...     ...   ...     ...
# 423001        Team Guarujá Inox       CrossFit Guaruja  Female  36.0     NaN
# 423002  FBP CrossFit Games Team           FBP CrossFit  Female  27.0     NaN
# 423003      CrossFit Oak Harbor    CrossFit Oak Harbor  Female  44.0     NaN
# 423004                      NaN            CrossFit 67  Female  20.0    64.0
# 423005                      NaN  Contra Costa CrossFit  Female  26.0     NaN
#
#         weight   fran  ...  snatch  deadlift  backsq  pullups  \
# 0        166.0    NaN  ...     NaN     400.0   305.0      NaN
# 1        190.0    NaN  ...     NaN       NaN     NaN      NaN
# 2          NaN    NaN  ...     NaN       NaN     NaN      NaN
# 3          NaN  211.0  ...   200.0     375.0   325.0     25.0
# 4        149.0  206.0  ...   150.0       NaN   325.0     50.0
# ...        ...    ...  ...     ...       ...     ...      ...
# 423001     NaN    NaN  ...     NaN       NaN     NaN      NaN
# 423002     NaN    NaN  ...     NaN       NaN     NaN      NaN
# 423003     NaN    NaN  ...     NaN       NaN     NaN      NaN
# 423004    61.0    NaN  ...     NaN      80.0   143.0      NaN
# 423005     NaN    NaN  ...     NaN       NaN     NaN      NaN
#
#                                                       eat  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                    I eat 1-3 full cheat meals per week|
# 4       I eat quality foods but don't measure the amount|
# ...                                                   ...
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004  I eat quality foods but don't measure the amount|
# 423005                                                NaN
#
#                                                     train  \
# 0       I workout mostly at a CrossFit Affiliate|I hav...
# 1       I have a coach who determines my programming|I...
# 2                                                     NaN
# 3       I workout mostly at a CrossFit Affiliate|I hav...
# 4       I workout mostly at a CrossFit Affiliate|I inc...
# ...                                                   ...
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004          I workout mostly at a CrossFit Affiliate|
# 423005                                                NaN
#
#                                                background  \
# 0       I played youth or high school level sports|I r...
# 1             I played youth or high school level sports|
# 2                                                     NaN
# 3             I played youth or high school level sports|
# 4                                I played college sports|
# ...                                                   ...
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004                                                NaN
# 423005                                                NaN
#
#                                                experience  \
# 0       I began CrossFit with a coach (e.g. at an affi...
# 1       I began CrossFit with a coach (e.g. at an affi...
# 2                                                     NaN
# 3       I began CrossFit by trying it alone (without a...
# 4       I began CrossFit by trying it alone (without a...
# ...                                                   ...
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004  I began CrossFit with a coach (e.g. at an affi...
# 423005                                                NaN
#
#                                                  schedule       howlong
# 0              I do multiple workouts in a day 2x a week|     4+ years|
# 1              I do multiple workouts in a day 2x a week|     4+ years|
# 2                                                     NaN           NaN
# 3                      I usually only do 1 workout a day|     4+ years|
# 4       I usually only do 1 workout a day|I strictly s...    1-2 years|
# ...                                                   ...           ...
# 423001                                                NaN           NaN
# 423002                                                NaN           NaN
# 423003                                                NaN           NaN
# 423004  I usually only do 1 workout a day|I strictly s...  6-12 months|
# 423005                                                NaN           NaN
#
# [423006 rows x 27 columns]

# %% [markdown]
# ## Commit to LakeFS

# %%
import lakefs_wrapper

lakefs_wrapper.commit_dataframe(data, version=1)
# Out:
# Failed committing transaction tx-c1dbe0fb-98f5-4bcd-bce9-8b3ad0ada2d0: code: 400, reason: Bad Request, body: {'message': 'commit: no changes'}

# %% [markdown]
# # Clean dataset

# %%
import numpy as np

# Remove not relevant columns
data = data.dropna(subset=['region','age','weight','height','howlong','gender','eat',
                           'train','background','experience','schedule','howlong',
                           'deadlift','candj','snatch','backsq','experience',
                           'background','schedule','howlong'])
data = data.drop(columns=['affiliate','team','name','athlete_id','fran','helen','grace',
                          'filthy50','fgonebad','run400','run5k','pullups','train'])

# Remove Outliers
data = data[data['weight'] < 1500]
data = data[data['gender'] != '--']
data = data[data['age'] >= 18]
data = data[(data['height'] < 96) & (data['height'] > 48)]

data = data[(data['deadlift'] > 0) & (data['deadlift'] <= 1105)|((data['gender'] == 'Female')
             & (data['deadlift'] <= 636))]
data = data[(data['candj'] > 0) & (data['candj'] <= 395)]
data = data[(data['snatch'] > 0) & (data['snatch'] <= 496)]
data = data[(data['backsq'] > 0) & (data['backsq'] <= 1069)]

# Clean Survey Data
decline_dict = {'Decline to answer|': np.nan}
data = data.replace(decline_dict)
data = data.dropna(subset=['background','experience','schedule','howlong','eat'])

# %% [markdown]
# ## Commit to LakeFS

# %%
import lakefs_wrapper

lakefs_wrapper.commit_dataframe(data, version=2)
# Out:
# Failed committing transaction tx-148be57c-fdc6-4eff-a5b4-b5b46170368d: code: 400, reason: Bad Request, body: {'message': 'commit: no changes'}

# %% [markdown]
# # Prepare Datasets

# %% [markdown]
# ## V1

# %%
data = lakefs_wrapper.load_dataframe(version=1)
display(data.head())
# Out:
#    athlete_id           name               region          team  \
# 0      2554.0      Pj Ablang           South West   Double Edge
# 1      3517.0  Derek Abdella                  NaN           NaN
# 2      4691.0            NaN                  NaN           NaN
# 3      5164.0    Abo Brandon  Southern California  LAX CrossFit
# 4      5286.0    Bryce Abbey                  NaN           NaN
#
#               affiliate gender   age  height  weight   fran  ...  snatch  \
# 0  Double Edge CrossFit   Male  24.0    70.0   166.0    NaN  ...     NaN
# 1                   NaN   Male  42.0    70.0   190.0    NaN  ...     NaN
# 2                   NaN    NaN   NaN     NaN     NaN    NaN  ...     NaN
# 3          LAX CrossFit   Male  40.0    67.0     NaN  211.0  ...   200.0
# 4                   NaN   Male  32.0    65.0   149.0  206.0  ...   150.0
#
#    deadlift  backsq  pullups  \
# 0     400.0   305.0      NaN
# 1       NaN     NaN      NaN
# 2       NaN     NaN      NaN
# 3     375.0   325.0     25.0
# 4       NaN   325.0     50.0
#
#                                                  eat  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3               I eat 1-3 full cheat meals per week|
# 4  I eat quality foods but don't measure the amount|
#
#                                                train  \
# 0  I workout mostly at a CrossFit Affiliate|I hav...
# 1  I have a coach who determines my programming|I...
# 2                                                NaN
# 3  I workout mostly at a CrossFit Affiliate|I hav...
# 4  I workout mostly at a CrossFit Affiliate|I inc...
#
#                                           background  \
# 0  I played youth or high school level sports|I r...
# 1        I played youth or high school level sports|
# 2                                                NaN
# 3        I played youth or high school level sports|
# 4                           I played college sports|
#
#                                           experience  \
# 0  I began CrossFit with a coach (e.g. at an affi...
# 1  I began CrossFit with a coach (e.g. at an affi...
# 2                                                NaN
# 3  I began CrossFit by trying it alone (without a...
# 4  I began CrossFit by trying it alone (without a...
#
#                                             schedule     howlong
# 0         I do multiple workouts in a day 2x a week|   4+ years|
# 1         I do multiple workouts in a day 2x a week|   4+ years|
# 2                                                NaN         NaN
# 3                 I usually only do 1 workout a day|   4+ years|
# 4  I usually only do 1 workout a day|I strictly s...  1-2 years|
#
# [5 rows x 27 columns]

# %%
import numpy as np
lifts = ["candj", "snatch", "deadlift", "backsq"]

X_v1 = data
y_v1 = np.sum(data[lifts], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_v1_train, X_v1_test, y_v1_train, y_v1_test = train_test_split(X_v1, y_v1, test_size=0.2)

# %% [markdown]
# ## V2

# %%
data = lakefs_wrapper.load_dataframe(version=2)
display(data.head())
# Out:
#                 region gender   age  height  weight  candj  snatch  deadlift  \
# 0  Southern California   Male  30.0    71.0   200.0  235.0   175.0     385.0
# 1               Africa   Male  28.0    70.0   176.0  187.0   134.0     335.0
# 2           North East   Male  35.0    68.0   225.0  285.0   205.0     440.0
# 3        North Central   Male  36.0    71.0   199.0  267.0   212.0     485.0
# 4           North East   Male  36.0    64.0   155.0  245.0   180.0     415.0
#
#    backsq                                                eat  \
# 0   315.0                      I eat whatever is convenient|
# 1   254.0               I eat 1-3 full cheat meals per week|
# 2   405.0  I eat quality foods but don't measure the amount|
# 3   390.0  I eat quality foods but don't measure the amount|
# 4   385.0                                I eat strict Paleo|
#
#                                           background  \
# 0  I played youth or high school level sports|I p...
# 1    I have no athletic background besides CrossFit|
# 2        I played youth or high school level sports|
# 3  I played youth or high school level sports|I p...
# 4  I played youth or high school level sports|I p...
#
#                                           experience  \
# 0  I began CrossFit by trying it alone (without a...
# 1  I began CrossFit with a coach (e.g. at an affi...
# 2  I began CrossFit with a coach (e.g. at an affi...
# 3  I began CrossFit with a coach (e.g. at an affi...
# 4  I began CrossFit by trying it alone (without a...
#
#                                             schedule     howlong
# 0  I do multiple workouts in a day 1x a week|I ty...  1-2 years|
# 1         I do multiple workouts in a day 1x a week|  2-4 years|
# 2         I typically rest 4 or more days per month|  2-4 years|
# 3  I do multiple workouts in a day 3+ times a wee...  1-2 years|
# 4  I do multiple workouts in a day 2x a week|I st...   4+ years|

# %%
X_v2 = data
y_v2 = np.sum(data[lifts], axis=1)

# %%
X_v2_train, X_v2_test, y_v2_train, y_v2_test = train_test_split(X_v2, y_v2, test_size=0.2)

# %% [markdown]
# # V1 EDA

# %%
display(X_v1_train.describe())
# Out:
#           athlete_id            age        height         weight  \
# count  338402.000000  264896.000000  1.280960e+05  183988.000000
# mean   292555.258196      32.515942  1.336230e+02     170.909972
# std    184946.923437       7.736737  2.343790e+04      62.565186
# min        86.000000      13.000000  0.000000e+00       1.000000
# 25%    134928.000000      27.000000  6.600000e+01     145.000000
# 50%    275649.500000      31.000000  6.900000e+01     170.000000
# 75%    472973.750000      37.000000  7.200000e+01     192.000000
# max    633083.000000     125.000000  8.388607e+06   20175.000000
#
#                fran         helen         grace      filthy50      fgonebad  \
# count  4.446000e+04  2.432300e+04  3.263200e+04  1.556400e+04  2.376200e+04
# mean   1.150952e+03  1.348237e+03  5.009961e+02  2.220983e+03  1.379908e+03
# std    8.039412e+04  7.613842e+04  4.651304e+04  6.748174e+04  9.447369e+04
# min    1.000000e+00  1.000000e+00 -6.000000e+01  1.000000e+00  0.000000e+00
# 25%    2.150000e+02  5.250000e+02  1.490000e+02  1.308000e+03  2.400000e+02
# 50%    2.900000e+02  5.950000e+02  1.930000e+02  1.548000e+03  2.950000e+02
# 75%    3.920000e+02  6.940000e+02  2.610000e+02  1.808000e+03  3.360000e+02
# max    8.388607e+06  8.388607e+06  8.388607e+06  8.388607e+06  8.388607e+06
#
#              run400         run5k         candj        snatch      deadlift  \
# count  1.785300e+04  2.899600e+04  8.355300e+04  7.782600e+04  9.226500e+04
# mean   6.055327e+02  3.858489e+03  2.917680e+02  2.671446e+02  7.881238e+02
# std    6.279953e+04  1.395449e+05  2.903313e+04  3.028648e+04  6.174913e+04
# min    1.000000e+00  1.000000e+00 -4.500000e+01  0.000000e+00 -5.000000e+02
# 25%    6.200000e+01  1.241000e+03  1.430000e+02  1.050000e+02  2.550000e+02
# 50%    7.100000e+01  1.380000e+03  1.950000e+02  1.450000e+02  3.450000e+02
# 75%    8.400000e+01  1.560000e+03  2.350000e+02  1.850000e+02  4.150000e+02
# max    8.388607e+06  8.388607e+06  8.388607e+06  8.388607e+06  8.388607e+06
#
#              backsq       pullups
# count  8.845000e+04  4.050400e+04
# mean   6.639912e+02  5.309364e+04
# std    5.648213e+04  1.067041e+07
# min   -7.000000e+00 -6.000000e+00
# 25%    2.050000e+02  1.500000e+01
# 50%    2.750000e+02  2.700000e+01
# 75%    3.350000e+02  4.000000e+01
# max    8.388607e+06  2.147484e+09

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 8))
sns.boxplot(data=X_v1_train[data.select_dtypes(include=np.number).columns])
plt.title("Feature Distribution")
plt.tight_layout()
plt.yscale('log')
plt.show()

# %%
corr = X_v1_train[data.select_dtypes(include=np.number).columns].corr()
plt.figure(figsize=(8, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # V1 Pipeline

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer

categorical_cols = ["region", "eat", "background", "experience", "schedule", "gender", "howlong"]
numerical_cols = ["age", "weight", "height"]

preprocessor = ColumnTransformer(
    transformers=[
        ("scale", StandardScaler(), numerical_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), categorical_cols)
    ],
)

model = make_pipeline(preprocessor, HistGradientBoostingRegressor())

# %%
model.fit(X_v1_train, y_v1_train)
predictions = model.predict(X_v1_test)

# %% [markdown]
# # V1 Metrics

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_percentage_error

rmse = root_mean_squared_error(y_v1_test, predictions)
mape = mean_absolute_percentage_error(y_v1_test, predictions)
print("RMSE:", rmse)
print("MAPE:", mape)
# Out:
# RMSE: 8623.89625090681
# MAPE: 1.21126300738457e+18

# %% [markdown]
# # V2 EDA

# %%
display(X_v2_train.describe())
# Out:
#                 age        height        weight         candj        snatch  \
# count  24023.000000  24023.000000  24023.000000  24023.000000  24023.000000
# mean      32.176414     68.853307    177.006535    205.408192    156.210007
# std        7.450244      3.781581     32.305750     58.661068     48.861145
# min       18.000000     54.000000      5.000000      1.000000      1.000000
# 25%       27.000000     66.000000    155.000000    160.000000    120.000000
# 50%       31.000000     69.000000    178.000000    205.000000    155.000000
# 75%       37.000000     72.000000    196.000000    245.000000    190.000000
# max       56.000000     83.000000    444.000000    390.000000    386.000000
#
#            deadlift        backsq
# count  24023.000000  24023.000000
# mean     361.899346    294.019107
# std       96.757524     85.200565
# min        0.000000      1.000000
# 25%      287.000000    225.000000
# 50%      370.000000    300.000000
# 75%      435.000000    355.000000
# max     1000.000000    882.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.boxplot(data=X_v2_train)
plt.title("Feature Distribution")
plt.tight_layout()
plt.show()

# %%
corr = X_v2_train[data.select_dtypes(include=np.number).columns].corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # V2 Pipeline

# %%
model.fit(X_v2_train, y_v2_train)
predictions = model.predict(X_v2_test)

# %% [markdown]
# # V2 Metrics

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_percentage_error
rmse = root_mean_squared_error(y_v2_test, predictions)
mape = mean_absolute_percentage_error(y_v2_test, predictions)
print("RMSE:", rmse)
print("MAPE:", mape)
# Out:
# RMSE: 141.01824091933764
# MAPE: 0.13993604774008442

# %% [markdown]
# # Compute DP

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from opacus import PrivacyEngine

preprocessor = ColumnTransformer(
    transformers=[
        ("scale", StandardScaler(), numerical_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), categorical_cols)
    ]
)

# Transform data
X_train_transformed = preprocessor.fit_transform(X_v2_train)
X_test_transformed = preprocessor.transform(X_v2_test)

# Convert to tensors (fixed version)
X_train_tensor = torch.tensor(X_train_transformed, dtype=torch.float32)
y_train_tensor = torch.tensor(y_v2_train.to_numpy(), dtype=torch.float32).view(-1, 1)
X_test_tensor = torch.tensor(X_test_transformed, dtype=torch.float32)
y_test_tensor = torch.tensor(y_v2_test.to_numpy(), dtype=torch.float32).view(-1, 1)

# Create datasets and loaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
# Create datasets and loaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# Define PyTorch model
class RegressionModel(nn.Module):
    def __init__(self, input_dim):
        super(RegressionModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Initialize model
input_dim = X_train_transformed.shape[1]
model = RegressionModel(input_dim)

# Set up optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=0.005)

# Make model differentially private
privacy_engine = PrivacyEngine()
model, optimizer, train_loader = privacy_engine.make_private(
    module=model,
    optimizer=optimizer,
    data_loader=train_loader,
    noise_multiplier=1.1,
    max_grad_norm=1.0,
)

# Training loop
criterion = nn.MSELoss()
num_epochs = 25
for epoch in range(num_epochs):
    model.train()
    for batch in train_loader:
        X, y = batch
        optimizer.zero_grad()
        output = model(X)
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {loss.item()}")
# Out:
# /home/ubuntu/.virtualenvs/pytorch/lib/python3.12/site-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
#   warnings.warn(
# Epoch 1/25, Loss: 1063391.875
# Epoch 2/25, Loss: 1009428.25
# Epoch 3/25, Loss: 917108.125
# Epoch 4/25, Loss: 495446.5
# Epoch 5/25, Loss: 173287.796875
# Epoch 6/25, Loss: 53610.51953125
# Epoch 7/25, Loss: 53126.9765625
# Epoch 8/25, Loss: 45184.734375
# Epoch 9/25, Loss: 53123.89453125
# Epoch 10/25, Loss: 34617.12890625
# Epoch 11/25, Loss: 26297.205078125
# Epoch 12/25, Loss: 50119.76171875
# Epoch 13/25, Loss: 34961.85546875
# Epoch 14/25, Loss: 23440.458984375
# Epoch 15/25, Loss: 30866.853515625
# Epoch 16/25, Loss: 26969.544921875
# Epoch 17/25, Loss: 31728.130859375
# Epoch 18/25, Loss: 24870.654296875
# Epoch 19/25, Loss: 14523.2646484375
# Epoch 20/25, Loss: 33756.22265625
# Epoch 21/25, Loss: 37294.4375
# Epoch 22/25, Loss: 13977.83203125
# Epoch 23/25, Loss: 31715.48046875
# Epoch 24/25, Loss: 19428.60546875
# Epoch 25/25, Loss: 13215.634765625

# %% [markdown]
# # Metrics

# %%
model.eval()
with torch.no_grad():
    predictions = model(X_test_tensor)
    predictions_np = predictions.numpy()
    y_test_np = y_test_tensor.numpy()
    rmse = root_mean_squared_error(y_test_np, predictions_np)
    mape = mean_absolute_percentage_error(y_test_np, predictions_np)
    print(f"RMSE: {rmse}")
    print(f"MAPE: {mape}")

epsilon = privacy_engine.accountant.get_epsilon(delta=1e-5)
print(f"Epsilon: {epsilon}")
# Out:
# RMSE: 159.65994262695312
# MAPE: 0.15587733685970306
# Epsilon: 0.7794011274190993
